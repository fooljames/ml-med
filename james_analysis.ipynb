# %%
import pandas as pd
import pandas_profiling as pp
import numpy as np
import time
from utils import *
import seaborn as sns

# %%
data = load_data(data_path="new_dataset.csv", colname_path="column_id_name.csv")
# Out:
# /Users/fooljames/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2821: DtypeWarning: Columns (73) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):

# %%
setting, measurement = separate_type(data)

# %%
pp.ProfileReport(setting)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...

# %%
measurement.head()
# Out:
#   dataset_location  dataset_datetime  Expired O2  Respiratory Rate  \
# 0     MICU2-6FL-B7    20171030181420         NaN              29.0
# 1     MICU2-6FL-B8    20171030181421         NaN              38.0
# 2     MICU2-6FL-B8    20171030181422         NaN               NaN
# 3     MICU2-6FL-B8    20171030181422         NaN               NaN
# 4     MICU2-6FL-B4    20171030181422         NaN               NaN
#
#    Inspired O2 (FiO2)  Mean Airway Pressure  Dynamic Compliance  \
# 0                 NaN                   8.0                83.0
# 1                 NaN                  14.0                68.0
# 2                 NaN                   NaN                 NaN
# 3                 NaN                   NaN                 NaN
# 4                 NaN                   NaN                 NaN
#
#    Minute Volume (Spontaneous)  Minute Volume Lower Alarm Limit  \
# 0                         0.54                              NaN
# ...

# %%
sns.set(style="ticks")
sns.pairplot(measurement.iloc[:, 2:].sample(1000))

# %%
set(measurement.columns[measurement.nunique() > 1]) - {'dataset_location', 'dataset_datetime'}
# Out:
# {'Airway Resistance',
#  'Alarm Silence Status',
#  'Breathing Circuit Compliance',
#  'Breathing Circuit Leak',
#  'Dynamic Compliance',
#  'Expired Minute Volume',
#  'Expired Tidal Volume',
#  'Expired Tidal Volume Lower Alarm Limit',
#  'Expired Tidal Volume Upper Alarm Limit',
#  'Extrinsic PEEP',
#  'Inspired Minute Volume (Total)',
#  'Inspired O2 (Ventilator)',
#  'Inspired Tidal Volume',
#  'Leakage (ventilator)',
#  'Maximum Positive Airway Pressure',
#  'Mean Airway Pressure',
#  'Mechancial Expired Minute Volume',
#  'Mechanical Expired Tidal Volume',
#  'Mechanical Respiratory Rate',
#  'Minute Volume (Spontaneous)',
#  'Minute Volume Upper Alarm Limit',
#  'Patient Disconnected',
#  'Peak Airway Pressure Lower Limit',
#  'Peak Airway Pressure Upper Limit',
#  'Peak Pressure Upper Alarm Limit',
#  'Rapid Shallow Breathing Index',
#  'Respiratory Rate',
#  'Respiratory Rate Lower Alarm Limit',
#  'Respiratory Rate Upper Alarm Limit',
# ...

# %%
x = measurement.columns.str.lower.contain()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-0a0b3ae1fe9d> in <module>()
# ----> 1 x = measurement.columns.str.lower.contain()
#
# AttributeError: 'function' object has no attribute 'contain'

# %%
x
# Out:
# Index(['dataset_location', 'dataset_datetime', 'expired o2',
#        'respiratory rate', 'inspired o2 (fio2)', 'mean airway pressure',
#        'dynamic compliance', 'minute volume (spontaneous)',
#        'minute volume lower alarm limit', 'minute volume upper alarm limit',
#        'rapid shallow breathing index', 'airway resistance', 'extrinsic peep',
#        'patient id', 'inspired tidal volume', 'expired tidal volume',
#        'expired minute volume', 'ventilator operation mode',
#        'mechanical expired tidal volume', 'spontaneous expired tidal volume',
#        'mechancial expired minute volume', 'mechanical respiratory rate',
#        'spontaneous respiratory rate', 'respiratory rate lower alarm limit',
#        'respiratory rate upper alarm limit', 'patient disconnected',
#        'maximum positive airway pressure',
#        'expired tidal volume upper alarm limit',
#        'expired tidal volume lower alarm limit', 'respiratory rate (co2)',
# ...
