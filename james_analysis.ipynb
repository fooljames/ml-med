# %%
import pandas as pd
import pandas_profiling as pp
import numpy as np
import time
from utils import *
import seaborn as sns

# %matplotlib inline

# %%
data = load_data(data_path="_data/capsule-20171113.csv", colname_path="column_id_name.csv")
data = addTimeInSec(data)
data = mean_by_interval(data, 10)

# %%
import plotly.plotly as py
from plotly.graph_objs import Scatter, Figure, Layout
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from plotly import tools

fig = tools.make_subplots(rows=3, cols=1, subplot_titles=('Mean Airway Pressure', 'Respiratory Rate', 'Inspired O2'))

for locat in data.dataset_location.unique():
    df_locat = data[data.dataset_location==locat].copy()
    
    fig.append_trace(Scatter(x=df_locat.datetime_interval, y=df_locat['Mean Airway Pressure'], name=locat+'_MAP'), 1, 1)
    fig.append_trace(Scatter(x=df_locat.datetime_interval, y=df_locat['Respiratory Rate'], name=locat+'_RR'), 2, 1)
    fig.append_trace(Scatter(x=df_locat.datetime_interval, y=df_locat['Inspired O2 (Ventilator)'], name=locat+'_IO'), 3 ,1)

    del df_locat

plot(fig)
# Out:
# This is the format of your plot grid:
# [ (1,1) x1,y1 ]
# [ (2,1) x2,y2 ]
# [ (3,1) x3,y3 ]
# 'file:///Users/fooljames/work/kku_mlmed/mlmed/temp-plot.html'

# %%
ax = data_min.plot(y='Mean Airway Pressure', figsize=(5,2))
ax.set(ylabel='Mean Airway Pressure')

ax = data_min.plot(y='Respiratory Rate', figsize=(5,2))
ax.set(ylabel='Respiratory Rate')

ax = data_min.plot(y='Inspired O2 (Ventilator)', figsize=(5,2))
ax.set(ylabel='Inspired O2 (Ventilator)')

# %%
measurement_min.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-49ba99d125a0> in <module>()
# ----> 1 measurement_min.columns
#
# NameError: name 'measurement_min' is not defined

# %%
setting_profile_min = pp.ProfileReport(setting_min)
measurement_profile_min = pp.ProfileReport(measurement_min)

setting_profile_min.to_file(outputfile="setting_profile_min.html")
measurement_profile_min.to_file(outputfile="measurement_profile_min.html")
# Out:
# /Users/fooljames/anaconda/lib/python3.6/site-packages/pandas_profiling/base.py:223: RuntimeWarning: divide by zero encountered in long_scalars
#   'p_unique': distinct_count / count}
# /Users/fooljames/anaconda/lib/python3.6/site-packages/pandas_profiling/base.py:223: RuntimeWarning: divide by zero encountered in long_scalars
#   'p_unique': distinct_count / count}
# /Users/fooljames/anaconda/lib/python3.6/site-packages/pandas_profiling/base.py:223: RuntimeWarning: divide by zero encountered in long_scalars
#   'p_unique': distinct_count / count}
# /Users/fooljames/anaconda/lib/python3.6/site-packages/pandas_profiling/base.py:223: RuntimeWarning: divide by zero encountered in long_scalars
#   'p_unique': distinct_count / count}
